# %%
from Slug_to_events import collect_slugs
collect_slugs()
# Out:
# NEXT CURSOR LXBrPTExODk1NjM4NzUz
# [{'_id': 'apes-stars-club'}, {'_id': 'crypto-punk-bros'}, {'_id': 'crazyboredapeclub'}, {'_id': 'lady-apes-yacht-club'}, {'_id': 'penguinbrosclub'}, {'_id': 'halo-official'}, {'_id': 'ai-technologies'}, {'_id': 'mutant-boredape'}, {'_id': 'we-asuki'}, {'_id': 'boredfrens'}, {'_id': 'aicandy'}, {'_id': 'boredfrens'}, {'_id': 'metaverse-new-human'}, {'_id': 'mesmerizer'}, {'_id': 'knights-of-degen-official'}, {'_id': 'apes-stars-club'}, {'_id': 'untitled-collection-4271575568'}, {'_id': 'ens'}, {'_id': 'akuma-moekko'}, {'_id': 'seizonofficial'}]
# NEXT CURSOR LXBrPTExODk1NjM4NDM4
# ...

# %%
from pymongo import MongoClient
client = MongoClient()
db = client.NFTDB
collection_data = db.slugCollection
print(db.slugCollection.count_documents({}))
# Out:
# 795
