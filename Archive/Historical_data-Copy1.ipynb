# %%
# %load_ext autoreload
# %autoreload 2

from Openseas_Methods import *
import networkx as nx
import matplotlib.pyplot as plt
import pickle
import pygraphviz
import random
from pymongo import MongoClient
from tqdm import tqdm
from datetime import datetime
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
date = "2023-01-01T11:59:59"
before = datetime.strptime(date,'%Y-%m-%dT%H:%M:%S')
date = "2022-01-01T11:59:59"
after = datetime.strptime(date,'%Y-%m-%dT%H:%M:%S')

# %%
from pymongo import MongoClient
client = MongoClient()
db =client.NFTDB
slug_data = db.completedSlugs
slugs = slug_data.find({},{'_id':1})
slug_list = list(slugs)
selected_slugs = [list(x.values())[0] for x in slug_list]

# %%
for slug in selected_slugs[100:]:
    pull_sales_data(collection_slug = slug,event_type='successful',before=before,API_KEY="55544646a70c491c80991e0666e7dbf6")
# Out:
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# Completed Slug in database
# ...
