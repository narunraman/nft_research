# %%
# %load_ext autoreload
# %autoreload 2
from Openseas_Methods import *
import matplotlib.pyplot as plt
import pickle
import pandas as pd
from pymongo import MongoClient
from tqdm import tqdm
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
API_KEY = "fa400fba3fd44574b659bb0372b8b5d9"

# %%
client = MongoClient()
#Pulls all sales converts to pandas
db = client.NFTDB
sales = db.salesCollection
record = sales.find({})
df = pd.DataFrame.from_records(record)

# %%
collection_slugs = list(pd.DataFrame.from_records(db.completedSlugs.find({}))['_id'])
collection_slugs[-10:]
# Out:
# ['town-star',
#  'mypethooligan',
#  'refik-anadol',
#  'pudgypenguins',
#  'cool-cats-nft',
#  'chromie-squiggle-by-snowfro',
#  'gay-aliens-society-gen-1',
#  'akidcalledbeast',
#  'veefriends-series-2',
#  'sproto-gremlins']

# %%
for collection_slug in tqdm(collection_slugs[::-1]):
    pull_listing_data(collection_slug, API_KEY = API_KEY)
# Out:
#   0%|                                                    | 0/77 [00:00<?, ?it/s]
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# <Response [429]>
# error
# ...
