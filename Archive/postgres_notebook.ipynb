# %%
import psql_methods as psql

# %%
# commands = ["CREATE TABLE nfttosale (contract VARCHAR(255),token_id VARCHAR(255),sale_price FLOAT);"]
commands = ["select * from nfttosales"]
data = psql.execute_commands(commands)
data
# Out:
# relation "nfttosale" does not exist
# LINE 1: select * from nfttosale
#                       ^

# %%
data_dict = {x[0]:x[1] for x in data}

# %%
data_dict
# Out:
# {'azukielementals': '0xb6a37b5d14d502c3ab0ae6f3a0e058bc9517786e',
#  'sproto-gremlins': '0xeeca64ea9fcf99a22806cd99b3d29cf6e8d54925',
#  'projectkaito': '0x31a7d612788277457c03e34ecd4efe4d6e6a8e39',
#  'ether-name-service': '0xcc7187ddbe8f099d31bac88d8d67f793001d718e',
#  'rainbow-maker': '0x107bab19022bb5e123560981bf16a1a46ecea99a',
#  'tvospecial': '0x72d70aa10fe0e5878e7caa451ac9a7b65fc05aa9',
#  'mcxeditions': '0xbc20b5f2c775fd5a829a451a5c5811a4ca76d5ed',
#  'mgminft': '0xd563272eea17f8ce929171c2ba62b1c7fb4756ae',
#  'slicednft': '0x439d2c641d097efd0a53609e6018387e17b1be4b',
#  'broadside-episodes': '0xfbe27c27dc2ef6a37256e0d0efaa4ddb67c54db7',
#  'kawaii-plushies-2': '0x5ac393ac3743eaa7bc47dbbca6a2f4f97fa44106',
#  'notjustakey': '0x05287b5dfd2a570a9311861fca3eb161c4a1f3ae',
#  'mike-karolos': '0x48a2c36fc89f5c15766acaf1c42e8e4ea005b3dc',
#  'yon-editions': '0x3364fa210fa91e0d6177ca9e3cb42ba24f9dfe87',
#  'hapebadge': '0x6fa9f4b50e2950a8137a76649193816fb29dad2c',
# ...
